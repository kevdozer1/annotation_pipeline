# %% [markdown]
# # BridgeEngine Benchmark Results

# %%
import pandas as pd
results = pd.read_csv('../bench_results/bench_results.csv')
results

# %%
results.groupby('family')['latent_mse'].agg(['mean', 'std']).sort_values('mean')
